# %% [markdown]
# <a href="https://colab.research.google.com/github/duytrung/QuanLyTuyenSinh/blob/main/Th%E1%BB%B1c_h%C3%A0nh_luy%E1%BB%87n_h%C3%A0m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bài tập trên lớp**

# %% [markdown]
# ## **Luyện tập viết hàm xử lý các bài toán quản trị phân tích mối quan hệ chi phí – khối lượng – lợi nhuận**

# %% [markdown]
# ### **💵 Số dư đảm phí**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Code hàm ở đây**

# %%
def so_du_dam_phi_toan_bo(doanh_thu:float, bien_phi_toan_bo:float):
  so_du_dam_phi = doanh_thu - bien_phi_toan_bo
  return so_du_dam_phi

def so_du_dam_phi_1_sp(gia_ban_1_sp:float, bien_phi_1_sp:float):
  so_du_dam_phi = gia_ban_1_sp - bien_phi_1_sp
  return so_du_dam_phi

# %% [markdown]
# Test Case Mẫu
# + Tổng doanh thu: 1000000, Tổng biến phí: 700000
#   + Kết quả: 300000
#
# + Giá bán sản phẩm: 200, Biến phí sản phẩm: 120
#   + Kết quả: 80
#
# + Doanh thu: 500000, Biến phí: 400000
#   + Kết quả: Số dư đảm phí = 100000

# %% [markdown]
# ### **Yêu cầu**: Sử dụng hàm trên để tính số dư đảm phí.

# %% [markdown]
# + Bài Tập 1: Tính số dư đảm phí toàn bộ sản phẩm
#   + Doanh thu toàn bộ sản phẩm: 2500000
#   + Biến phí toàn bộ sản phẩm: 1800000

# %%
so_du_dam_phi = so_du_dam_phi_toan_bo(2500000, 1800000)
print(f"Số dư đảm phí toàn bộ sản phẩm là: {so_du_dam_phi}")
# Out:
# Số dư đảm phí toàn bộ sản phẩm là: 700000

# %% [markdown]
# + Bài Tập 2: Tính số dư đảm phí cho một sản phẩm
#   + Giá bán sản phẩm: 350
#   + Biến phí sản phẩm: 200

# %%
so_du_dam_phi_1_sp = so_du_dam_phi_1_sp(350, 200)
print(f"Số dư đảm phí cho một sản phẩm là: {so_du_dam_phi_1_sp}")
# Out:
# Số dư đảm phí cho một sản phẩm là: 150

# %% [markdown]
# + Bài Tập 3: Tính số dư đảm phí và lợi nhuận
#   + Doanh thu toàn bộ sản phẩm: 3000000
#   + Biến phí toàn bộ sản phẩm: 2200000
#   + Chi phí bất biến: 600000
#
# **Gợi ý**: Tính số dư đảm phí và lợi nhuận (Lợi nhuận = Số dư đảm phí - Chi phí bất biến).

# %% [markdown]
# ### **📊 Tỷ lệ số dư đảm phí**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Code hàm ở đây**

# %%
def ty_le_so_du_dam_phi_1(tong_doanh_thu:float = 0, tong_so_du:float = 0):
  if tong_doanh_thu == 0:
    print("Bạn quên nhập tổng doanh thu")
    return None
  ty_le_so_du = (tong_so_du / tong_doanh_thu) * 100
  return ty_le_so_du

def ty_le_so_du_dam_phi_2(gia_ban:float, bien_phi:float):
  ty_le_so_du = ((gia_ban - bien_phi) / gia_ban) * 100
  return ty_le_so_du

# %% [markdown]
# **Test Case Mẫu**
#
# + Tổng doanh thu: 1,000,000, Tổng số dư đảm phí: 300,000
#   + Tỷ lệ số dư đảm phí: 30%
#
# + Giá bán sản phẩm: 200, Biến phí sản phẩm: 120
#   + Tỷ lệ số dư đảm phí: 40%

# %% [markdown]
# ### **Yê cầu**: Sử dụng các hàm trên để tính tỷ lệ số dư đảm phí

# %% [markdown]
# + Bài Tập 1: Tính tỷ lệ số dư đảm phí toàn bộ sản phẩm
#   + Doanh thu toàn bộ sản phẩm: 2500000
#   + Số dư đảm phí toàn bộ sản phẩm: 700000
# Yêu cầu: Tính tỷ lệ số dư đảm phí.

# %%
ty_le_so_du = ty_le_so_du_dam_phi_1(700000)

if ty_le_so_du != None:
  print(f"Tỷ lệ số dư đảm phí là: {round(ty_le_so_du, 2)}") # Error Handling
# Out:
# Bạn quên nhập tổng doanh thu

# %% [markdown]
# + Bài Tập 2: Tính tỷ lệ số dư đảm phí cho một sản phẩm
#   + Giá bán sản phẩm: 350
#   + Biến phí sản phẩm: 200

# %%
example = round(10.67890)
print(example)
# Out:
# 11

# %% [markdown]
# + Bài Tập 3: Phân tích thay đổi tỷ lệ số dư đảm phí khi doanh thu thay đổi
#   + Trường hợp ban đầu - Doanh thu: 1000000
#   + Số dư đảm phí: 300000
#   + Doanh thu mới: 1200000
# + **Yêu cầu**: Tính tỷ lệ số dư đảm phí trước và sau khi doanh thu thay đổi, sau đó phân tích chênh lệch.

# %% [markdown]
# ### **🎯 Điểm hòa vốn**

# %% [markdown]
# ![Screenshot 2024-12-11 034659.png](data:image/png;base64,...)

# %% [markdown]
# ### **Code hàm ở đây**

# %% [markdown]
# **Test Case Mẫu**
# + Định phí: 500000, Số dư đảm phí một sản phẩm: 50
#   + Sản lượng tiêu thụ hòa vốn: 10000 sản phẩm
#
# + Định phí: 500000, Tỷ lệ số dư đảm phí: 40%
#   + Doanh thu hòa vốn: 1250000

# %% [markdown]
# ### **Yêu cầu**: Sử dụng các hàm trên để tính sản lượng tiêu thụ hòa vốn và doanh thu hòa vốn

# %% [markdown]
# + Bài Tập 1: Tính sản lượng tiêu thụ hòa vốn
#   + Định phí: 600,000
#   + Giá bán mỗi sản phẩm: 120
#   + Biến phí mỗi sản phẩm: 60
#   + **Yêu cầu:**<br>
#   1) Tính số dư đảm phí một sản phẩm.<br>
#   2) Dùng số dư đảm phí để tính sản lượng tiêu thụ hòa vốn.

# %% [markdown]
# + Bài Tập 2: Tính doanh thu hòa vốn
#   + Định phí: 800000
#   + Tổng doanh thu dự kiến: 2000000
#   + Biến phí tương ứng: 1200000
#   + Yêu cầu:<br>
#   1) Tính tỷ lệ số dư đảm phí.<br>
#   2) Dùng tỷ lệ số dư đảm phí để tính doanh thu hòa vốn.

# %% [markdown]
# + Bài Tập 3: Tính cả hai giá trị hòa vốn
#   + Định phí: 1000000
#   + Giá bán mỗi sản phẩm: 150
#   + Biến phí mỗi sản phẩm: 90
#   + Tổng doanh thu dự kiến: 3000000
#   + Biến phí tương ứng: 1800000
#   + Yêu cầu:
#
#   1) Tính số dư đảm phí một sản phẩm và tỷ lệ số dư đảm phí.
#
#   2) Dùng số dư đảm phí để tính sản lượng tiêu thụ hòa vốn.
#
#   3) Dùng tỷ lệ số dư đảm phí để tính doanh thu hòa vốn.

# %% [markdown]
# + Bài Tập 4: Phân tích thay đổi khi định phí tăng
#   + Trường hợp ban đầu => Định phí: 500000
#   + Giá bán mỗi sản phẩm: 100
#   + Biến phí mỗi sản phẩm: 50
#   + Tổng doanh thu dự kiến: 1500000
#   + Biến phí tương ứng: 900000
#   + Trường hợp mới => Định phí: 600000
#   + Yêu cầu:<br>
#   1) Tính số dư đảm phí một sản phẩm và tỷ lệ số dư đảm phí trong cả hai trường hợp.<br>
#   2) Tính sản lượng tiêu thụ hòa vốn và doanh thu hòa vốn trong cả hai trường hợp.<br>
#   3) Phân tích sự thay đổi.

# %% [markdown]
# #### **Phân tích**

# %% [markdown]
# + Khi định phí tăng từ 500.000 lên 600.000, sản lượng hòa vốn cần tăng thêm 2.000 sản phẩm, và doanh thu hòa vốn cần tăng thêm 250.000 VND để đạt hòa vốn.
# + Khuyến nghị: Tìm cách tối ưu định phí hoặc tăng giá bán để giảm áp lực hòa vốn.

# %% [markdown]
# # **Bài tập về nhà**

# %% [markdown]
# ## **Phân tích biến động chi phí nguyên vật liệu trực tiếp - Giải thích**

# %% [markdown]
# **Phân tích biến động chi phí nguyên vật liệu trực tiếp**
#
# – Xác định chỉ tiêu phân tích
#
# + C0 = Q1*m0*G0
# + C1 = Q1*m1*G1
# + C0: Chi phí nguyên vật liệu trực tiếp định mức
# + C1: Chi phí nguyên vật liệu trực tiếp thực tế
# + Q1: Số lượng sản phẩm sản xuất thực tế
# + m0: Lượng nguyên vật liệu trực tiếp định mức sản xuất 1 sản phẩm
# + m1: Lượng nguyên vật liệu trực tiếp thực tế sản xuất 1 sản phẩm
# + G0: Giá mua định mức 1 đơn vị nguyên vật liệu trực tiếp
# + G1: Giá mua thực tế 1 đơn vị nguyên vật liệu trực tiếp
#
# – Xác định đối tượng phân tích
#
# – Biến động chi phí (∆C):
# + ∆C = C1 – C0
# + ∆C > 0: bất lợi
# + ∆C <= 0: thuận lợi
#
# – Xác định ảnh hưởng của các nhân tố (công thức kế toán quản trị)
#
# Lượng nguyên vật liệu trực tiếp tiêu hao – biến động lượng (∆Cm):
#
# Cố định nhân tố giá mua nguyên vật liệu trực tiếp theo trị số định mức:
#
# + ∆Cm = Q1*m1*G0 – Q1*m0*G0
# + ∆Cm > 0: bất lợi
# + ∆Cm <= 0: thuận lợi
#
# Giá mua nguyên vật liệu trực tiếp – biến động giá (∆CG):
#
# Cố định nhân tố lượng nguyên vật liệu trực tiếp tiêu hao theo trị số thực tế:
#
# + ∆CG = Q1*m1*G1 – Q1*m1*G0
# + ∆CG > 0: bất lợi
# + ∆CG <= 0: thuận lợi

# %% [markdown]
# ## **Phân tích biến động chi phí nguyên vật liệu trực tiếp - Bài tập áp dụng**

# %% [markdown]
# ### **1) Tính tổng chi phí nguyên vật liệu**

# %% [markdown]
# Đề bài:
#
# + Công ty sản xuất 1.000 sản phẩm trong kỳ.
#
# + Định mức tiêu hao nguyên vật liệu để sản xuất 1 sản phẩm là 5 kg, với giá định mức là 10.000 VND/kg.
#
# + Lượng nguyên vật liệu thực tế tiêu hao để sản xuất 1 sản phẩm là 6 kg, với giá thực tế là 12.000 VND/kg.
#
# Yêu cầu:
#
# > 1) Tính chi phí nguyên vật liệu định mức (C0).
#
# > 2) Tính chi phí nguyên vật liệu thực tế (C1).
#
# > 3) Tính biến động chi phí nguyên vật liệu (∆C) và nhận xét.

# %% [markdown]
# ### **2) Phân tích biến động lượng tiêu hao nguyên vật liệu**

# %% [markdown]
# Đề bài:
#
# + Công ty sản xuất 500 sản phẩm trong kỳ.
#
# + Định mức tiêu hao nguyên vật liệu: 4 kg/sản phẩm.
#
# + Thực tế tiêu hao: 4,5 kg/sản phẩm.
#
# + Giá mua định mức: 20.000 VND/kg.
#
# Yêu cầu:
#
# > Tính biến động lượng tiêu hao nguyên vật liệu (∆Cm) khi cố định giá mua nguyên vật liệu theo định mức.
#
# > Xác định biến động này là thuận lợi hay bất lợi.

# %% [markdown]
# ### **3) Phân tích biến động giá nguyên vật liệu**

# %% [markdown]
# Đề bài:
#
# + Số lượng sản phẩm sản xuất: 2.000 sản phẩm.
# + Lượng nguyên vật liệu thực tế tiêu hao: 3 kg/sản phẩm.
# + Giá mua định mức: 8.000 VND/kg.
# + Giá mua thực tế: 9.000 VND/kg.
#
# Yêu cầu:
#
# > Tính biến động giá nguyên vật liệu (∆CG) khi cố định lượng nguyên vật liệu theo trị số thực tế.
#
# > Xác định biến động này là thuận lợi hay bất lợi.

# %% [markdown]
# ### **4) Tổng hợp phân tích biến động chi phí**

# %% [markdown]
# Đề bài:
#
# + Công ty sản xuất 800 sản phẩm.
# + Định mức nguyên vật liệu: 2,5 kg/sản phẩm.
# + Thực tế tiêu hao: 3 kg/sản phẩm.
# + Giá mua định mức: 15.000 VND/kg.
# + Giá mua thực tế: 16.000 VND/kg.
#
# Yêu cầu:
#
# > Tính chi phí nguyên vật liệu định mức (C0) và thực tế (C1).
#
# > Tính biến động chi phí (∆C).
#
# > Phân tích nguyên nhân biến động từ hai nhân tố:
#
# > Lượng nguyên vật liệu tiêu hao (∆Cm).
#
# > Giá nguyên vật liệu mua vào (∆CG).
#
# > Nhận xét và đưa ra đề xuất cải thiện.

# %% [markdown]
# ### **5) So sánh giữa các kỳ**

# %% [markdown]
# Đề bài:
#
# + Kỳ 1: Công ty sản xuất 1.500 sản phẩm, tiêu hao thực tế 4 kg/sản phẩm, giá mua thực tế 10.000 VND/kg.
# + Kỳ 2: Công ty sản xuất 2.000 sản phẩm, tiêu hao thực tế 3,8 kg/sản phẩm, giá mua thực tế 11.000 VND/kg.
# + Định mức tiêu hao nguyên vật liệu: 4 kg/sản phẩm.
# + Giá mua định mức: 10.000 VND/kg.
#
# Yêu cầu:
#
# > Tính chi phí nguyên vật liệu thực tế (C1) cho từng kỳ.
#
# > So sánh biến động chi phí giữa kỳ 1 và kỳ 2.
#
# > Phân tích nguyên nhân biến động từ các nhân tố lượng (∆Cm) và giá (∆CG).

# %% [markdown]
# ### **6) Ứng dụng trong lập kế hoạch sản xuất**

# %% [markdown]
# Đề bài:
#
# + Doanh nghiệp dự định sản xuất 3.000 sản phẩm trong tháng tới.
# + Định mức tiêu hao: 5 kg/sản phẩm.
# + Giá mua định mức: 12.000 VND/kg.
# + Ban quản lý ước tính:
# + Lượng tiêu hao thực tế có thể tăng lên 5,5 kg/sản phẩm.
# + Giá mua nguyên vật liệu dự kiến là 13.000 VND/kg.
#
# Yêu cầu:
#
# > Tính chi phí nguyên vật liệu dự kiến (C1).
#
# > Tính mức chênh lệch giữa chi phí nguyên vật liệu dự kiến và định mức (∆C).
#
# > Đề xuất biện pháp giảm mức chênh lệch này.

# %% [markdown]
# #### **Phân tích kết quả**

# %% [markdown]
# 1) Chi phí định mức (C0):
# + Chi phí dựa trên định mức là 180.000.000 VND.
#
# 2) Chi phí thực tế dự kiến (C1):
# + Chi phí thực tế dự kiến tăng lên 214.500.000 VND.
#
# 3) Biến động tổng chi phí (∆C):
# + Biến động là 34.500.000 VND, và trạng thái bất lợi.
#
# 4) Phân tích nguyên nhân:
# + Biến động lượng tiêu hao (∆Cm):
#   + Phát sinh thêm 18.000.000 VND do tiêu hao nguyên vật liệu tăng từ 5 kg/sản phẩm lên 5,5 kg/sản phẩm.
# + Biến động giá nguyên vật liệu (∆CG):
#   + Phát sinh thêm 16.500.000 VND do giá nguyên vật liệu tăng từ 12.000 VND/kg lên 13.000 VND/kg.

# %% [markdown]
# #### **Nhận xét và đề xuất**

# %% [markdown]
# 1) Nguyên nhân bất lợi:
#
# + Lượng tiêu hao tăng: Do sử dụng nhiều nguyên vật liệu hơn so với định mức.
# + Giá nguyên vật liệu tăng: Do biến động thị trường.
#
# 2) Đề xuất:
# + Kiểm soát lượng tiêu hao:
#   + Đào tạo nhân viên để tối ưu hóa sử dụng nguyên vật liệu.
#   + Nâng cấp công nghệ sản xuất để giảm hao hụt.
# + Quản lý chi phí mua hàng:
#   + Tìm kiếm nhà cung cấp mới để có giá tốt hơn.
#   + Đàm phán với nhà cung cấp hiện tại để giảm giá.
